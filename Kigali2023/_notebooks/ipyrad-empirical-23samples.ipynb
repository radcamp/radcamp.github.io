# %%
import ipyrad
import ipyrad.analysis as ipa
import toytree

# %%
data = "/home/osboxes/ipyrad-23samples/cheetah_outfiles/cheetah.snps.hdf5"
## Create the pca object
pca = ipa.pca(data, impute_method=None)
## Run the analysis
pca.run(nreplicates=5) 
## Bam!
pca.draw()
# Out:
# Samples: 24
# Sites before filtering: 6728
# Filtered (indels): 484
# Filtered (bi-allel): 26
# Filtered (mincov): 21
# Filtered (minmap): 0
# Filtered (subsample invariant): 14
# Filtered (minor allele frequency): 0
# Filtered (combined): 507
# Sites after filtering: 6222
# Sites containing missing values: 6209 (99.79%)
# Missing values in SNP matrix: 92096 (61.67%)
# SNPs (total): 6222
# SNPs (unlinked): 3973
# Imputation (null; sets to 0): 100.0%, 0.0%, 0.0%
# Subsampling SNPs: 3973/6222
# (<toyplot.canvas.Canvas at 0x7f90c3505090>,
#  <toyplot.coordinates.Cartesian at 0x7f90c2cde170>)
# ...

# %%
imap = {"A.j.jubatus":['SRR19760918','SRR19760920','SRR19760921','SRR19760924','SRR19760927','SRR19760928','SRR19760942','SRR19760946','SRR19760947','SRR19760956'],
        "A.j.soemmeringii":['SRR19760910','SRR19760912','SRR19760954','SRR19760955','SRR19760957','SRR19760958','SRR19760959','SRR19760960','SRR19760961','SRR19760962'],
        "A.j.venaticus":['SRR19760950','SRR19760951','SRR19760953'],
        "Outgroup":['SRR19760949']}

# %%
pca = ipa.pca(data, imap=imap)
pca.run()
pca.draw(label="Sims colored by pop")
# Out:
# Samples: 24
# Sites before filtering: 6728
# Filtered (indels): 484
# Filtered (bi-allel): 26
# Filtered (mincov): 21
# Filtered (minmap): 3904
# Filtered (subsample invariant): 14
# Filtered (minor allele frequency): 0
# Filtered (combined): 4028
# Sites after filtering: 2701
# Sites containing missing values: 2688 (99.52%)
# Missing values in SNP matrix: 33510 (51.69%)
# SNPs (total): 2701
# SNPs (unlinked): 1525
# Imputation (null; sets to 0): 100.0%, 0.0%, 0.0%
# Subsampling SNPs: 1525/2701
# (<toyplot.canvas.Canvas at 0x7f90c1b4c670>,
#  <toyplot.coordinates.Cartesian at 0x7f90c1b4f610>)
# ...

# %%
imap = {"A.j.jubatus":['SRR19760918','SRR19760920','SRR19760921','SRR19760924','SRR19760927','SRR19760928','SRR19760942','SRR19760946','SRR19760947','SRR19760956'],
        "A.j.soemmeringii":['SRR19760910','SRR19760912','SRR19760954','SRR19760955','SRR19760957','SRR19760958','SRR19760959','SRR19760960','SRR19760961','SRR19760962'],
        "A.j.venaticus":['SRR19760950','SRR19760951','SRR19760953']}
pca = ipa.pca(data, imap=imap)
pca.run()
pca.draw(label="Sims colored by pop (no outgroup)")
# Out:
# Samples: 23
# Sites before filtering: 6728
# Filtered (indels): 472
# Filtered (bi-allel): 15
# Filtered (mincov): 32
# Filtered (minmap): 2648
# Filtered (subsample invariant): 3619
# Filtered (minor allele frequency): 0
# Filtered (combined): 5145
# Sites after filtering: 1577
# Sites containing missing values: 1571 (99.62%)
# Missing values in SNP matrix: 20164 (55.59%)
# SNPs (total): 1577
# SNPs (unlinked): 1293
# Imputation (null; sets to 0): 100.0%, 0.0%, 0.0%
# Subsampling SNPs: 1293/1577
# (<toyplot.canvas.Canvas at 0x7f90c1b4a4d0>,
#  <toyplot.coordinates.Cartesian at 0x7f90c1b4b340>)
# ...

# %%
pca.run(nreplicates=10, seed=12345)
pca.draw();
# Out:
# Subsampling SNPs: 1293/1577
# ...

# %%
pca.draw(2,3)
# Out:
# (<toyplot.canvas.Canvas at 0x7f90c1b4c220>,
#  <toyplot.coordinates.Cartesian at 0x7f90c1bb7b20>)
# ...

# %%
pca.draw(colors=["hotpink", "skyblue", "goldenrod"])
pca.draw(outfile="/home/osboxes/ipyrad-workshop/cheetah-pca.pdf")
# Out:
# (<toyplot.canvas.Canvas at 0x7f91200bbfa0>,
#  <toyplot.coordinates.Cartesian at 0x7f90c1ba2290>)
# ...

# %%
# %%time
# Path to the input phylip file
phyfile = "/home/osboxes/ipyrad-23samples/minsamples10_outfiles/minsamples10.phy"
# init raxml object with input data and (optional) parameter options
# Total execution time: 476.184569
#rax = ipa.raxml(data=phyfile, T=4, N=2, f='E')
rax = ipa.raxml(data=phyfile, T=4, N=2, f='a')
# print the raxml command string for prosperity
print(rax.command)
# run the command, (options: block until finishes; overwrite existing)
rax.run(block=True, force=True)
# Out:
# /home/osboxes/miniconda3/envs/ipyrad/bin/raxmlHPC-PTHREADS-AVX2 -f a -T 4 -m GTRGAMMA -n test -w /home/osboxes/ipyrad-23samples/analysis-raxml -s /home/osboxes/ipyrad-23samples/minsamples10_outfiles/minsamples10.phy -p 54321 -N 2 -x 12345
# job test finished successfully
# CPU times: user 16.6 ms, sys: 2.41 ms, total: 19 ms
# Wall time: 1min 59s

# %%
# load from the .trees attribute of the raxml object, or from the saved tree file
tre = toytree.tree(rax.trees.bipartitions)
# draw the tree rooting on population 3
rtre = tre.root(wildcard="SRR19760949")
rtre.draw(tip_labels_align=True, node_labels="support");
# Out:
# <div class="toyplot" id="t8743fc7673ef490c8a7a4014ac08a1f9" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="305.0px" height="432.0px" viewBox="0 0 305.0 432.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tbe474fe01d184a8f9022605b0db6398d"><g class="toyplot-coordinates-Cartesian" id="t3fa951fc8f224fc5925af6275db3efe5"><clipPath id="t9f7c4f163f0e45faa6be569959a3597a"><rect x="30.0" y="30.0" width="245.0" height="372.0"></rect></clipPath><g clip-path="url(#t9f7c4f163f0e45faa6be569959a3597a)"><g class="toytree-mark-Toytree" id="t4128490253204b6eb2b446c7b25ccc05"><g class="toytree-Edges" style="fill:non
# ...

# %%
rax.params
# Out:
# N        2
# T        4
# binary   ~/miniconda3/envs/ipyrad/bin/raxmlHPC-PTHREADS-AVX2
# f        a
# m        GTRGAMMA
# n        test
# p        54321
# s        ~/ipyrad-workshop/minsamples30_outfiles/minsamples30.phy
# w        ~/src/notebooks/analysis-raxml
# x        12345

# %%
rtre.draw(node_sizes=15, node_labels="support")
# Out:
# (<toyplot.canvas.Canvas at 0x7f90c1bb6e30>,
# ...
#  <toytree.Render.ToytreeMark at 0x7f90c1da13c0>)
# ...

# %%
rtre.draw(tree_style='d')          # dark-style
rtre.draw(tree_style='o')          # umlaut-style
# Out:
# (<toyplot.canvas.Canvas at 0x7f90c1da0910>,
# ...
#  <toytree.Render.ToytreeMark at 0x7f90c1da2080>)
# ...

# %%
rtre.draw(tree_style="o", layout='d')
rtre.draw(tree_style="o", layout='c')
# Out:
# (<toyplot.canvas.Canvas at 0x7f90c1c7dd20>,
# ...
#  <toytree.Render.ToytreeMark at 0x7f90c2452dd0>)
# ...

# %%
imap = {"A.j.jubatus":['SRR19760918','SRR19760920','SRR19760921','SRR19760924','SRR19760927','SRR19760928','SRR19760942','SRR19760946','SRR19760947','SRR19760956'],
        "A.j.soemmeringii":['SRR19760910','SRR19760912','SRR19760954','SRR19760955','SRR19760957','SRR19760958','SRR19760959','SRR19760960','SRR19760961','SRR19760962'],
        "A.j.venaticus":['SRR19760950','SRR19760951','SRR19760953'],
        "Outgroup":['SRR19760949']}
colormap = {"A.j.jubatus":"red",
           "A.j.soemmeringii":"blue",
            "A.j.venaticus": "teal",
           "Outgroup":"black"}
colorlist = []
for sample in rtre.get_tip_labels():
    for species, samples in imap.items():
        if sample in samples:
            colorlist.append(colormap[species])

# %%
# make list of hex color values based on tip labels

rtre.draw(
    tip_labels_align=True,
    tip_labels_colors=colorlist
);
# Out:
# <div class="toyplot" id="t94b4bea5dce549c1aea7c385794fb09e" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="305.0px" height="432.0px" viewBox="0 0 305.0 432.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t00fb8677953147b4aad1cd66d1c0917b"><g class="toyplot-coordinates-Cartesian" id="t6e686f5c7321464291da607f82b88593"><clipPath id="t8e415d452c09420ea72d9336bbd18794"><rect x="30.0" y="30.0" width="245.0" height="372.0"></rect></clipPath><g clip-path="url(#t8e415d452c09420ea72d9336bbd18794)"><g class="toytree-mark-Toytree" id="tf3a915efa5694d27a2473bc184fb9be2"><g class="toytree-Edges" style="fill:non
# ...
